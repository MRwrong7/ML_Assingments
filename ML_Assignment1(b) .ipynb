# %% [markdown]
# <a href="https://colab.research.google.com/github/Gurjot-Singh-2002/UML501-Lab-Assignments/blob/main/102203582_3CO14_ODD2024_A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df['Name']=['a','b','c','d','e','f','g','h','i','j']
df['Age']=[10,9,8,7,6,5,4,3,2,15]
df['Roll no']=['120','121','122','123','124','125','126','127','128','129']
df['Gender']=['M','F','M','F','M','F','M','F','M','F']
df
# Out:
#   Name  Age Roll no Gender
# 0    a   10     120      M
# 1    b    9     121      F
# 2    c    8     122      M
# 3    d    7     123      F
# 4    e    6     124      M
# 5    f    5     125      F
# 6    g    4     126      M
# 7    h    3     127      F
# 8    i    2     128      M
# 9    j   15     129      F

# %%
df.to_csv('sample.csv')
from google.colab import files
files.download("sample.csv")

# %%
df.iloc[4], df.iloc[1:4], df.iloc[:], df.iloc[1:4, 5:8]
# Out:
# (Name         e
#  Age          6
#  Roll no    124
#  Gender       M
#  Name: 4, dtype: object,
#    Name  Age Roll no Gender
#  1    b    9     121      F
#  2    c    8     122      M
#  3    d    7     123      F,
#    Name  Age Roll no Gender
#  0    a   10     120      M
#  1    b    9     121      F
#  2    c    8     122      M
#  3    d    7     123      F
#  4    e    6     124      M
#  5    f    5     125      F
#  6    g    4     126      M
#  7    h    3     127      F
#  8    i    2     128      M
#  9    j   15     129      F,
#  Empty DataFrame
#  Columns: []
#  Index: [1, 2, 3])

# %%
df[df['Gender']=='M']
# Out:
#   Name  Age Roll no Gender
# 0    a   10     120      M
# 2    c    8     122      M
# 4    e    6     124      M
# 6    g    4     126      M
# 8    i    2     128      M

# %%
df.replace("F","Woman")
# Out:
#   Name  Age Roll no Gender
# 0    a   10     120      M
# 1    b    9     121  Woman
# 2    c    8     122      M
# 3    d    7     123  Woman
# 4    e    6     124      M
# 5    f    5     125  Woman
# 6    g    4     126      M
# 7    h    3     127  Woman
# 8    i    2     128      M
# 9    j   15     129  Woman

# %%
df['Gender'].replace(["Woman","male"],["M","man"])
# Out:
# 0    M
# 1    F
# 2    M
# 3    F
# 4    M
# 5    F
# 6    M
# 7    F
# 8    M
# 9    F
# Name: Gender, dtype: object

# %%
df
# Out:
#   Name  Age Roll no Gender
# 0    a   10     120      M
# 1    b    9     121      F
# 2    c    8     122      M
# 3    d    7     123      F
# 4    e    6     124      M
# 5    f    5     125      F
# 6    g    4     126      M
# 7    h    3     127      F
# 8    i    2     128      M
# 9    j   15     129      F

# %%
df.drop(['Gener'],axis=1)

# %%
df.rename(columns={'Gender':'Sex'})
# Out:
#   Name  Age Roll no Sex
# 0    a   10     120   M
# 1    b    9     121   F
# 2    c    8     122   M
# 3    d    7     123   F
# 4    e    6     124   M
# 5    f    5     125   F
# 6    g    4     126   M
# 7    h    3     127   F
# 8    i    2     128   M
# 9    j   15     129   F

# %%
df.rename(columns={'Sex':'Gender'})
# Out:
#   Name  Age Roll no Gender
# 0    a   10     120      M
# 1    b    9     121      F
# 2    c    8     122      M
# 3    d    7     123      F
# 4    e    6     124      M
# 5    f    5     125      F
# 6    g    4     126      M
# 7    h    3     127      F
# 8    i    2     128      M
# 9    j   15     129      F

# %%
a=df['Age'].max()
print(a)
# Out:
# 15

# %%
b=df['Age'].min()
print(b)
# Out:
# 2

# %%
print(df['Age'].sum())
# Out:
# 69

# %%
print(df['Age'].mean())
# Out:
# 6.9

# %%
print(df['Age'].count())
# Out:
# 10

# %%
print(df['Gender'].unique())
# Out:
# ['M' 'F']

# %%
print(df['Gender'].nunique())
# Out:
# 2

# %%
print(df['Gender'].value_counts())
# Out:
# Gender
# M    5
# F    5
# Name: count, dtype: int64

# %%
df.drop(['Age'],axis=1)
# Out:
#   Name Roll no Gender
# 0    a     120      M
# 1    b     121      F
# 2    c     122      M
# 3    d     123      F
# 4    e     124      M
# 5    f     125      F
# 6    g     126      M
# 7    h     127      F
# 8    i     128      M
# 9    j     129      F

# %%
df[df['Gender']!='M']
# Out:
#   Name  Age Roll no Gender
# 1    b    9     121      F
# 3    d    7     123      F
# 5    f    5     125      F
# 7    h    3     127      F
# 9    j   15     129      F

# %%
df.groupby('Gender')

# %%
print(df.groupby('Age').sum())
# Out:
#     Name Roll no Gender
# Age
# 2      i     128      M
# 3      h     127      F
# 4      g     126      M
# 5      f     125      F
# 6      e     124      M
# 7      d     123      F
# 8      c     122      M
# 9      b     121      F
# 10     a     120      M
# 15     j     129      F

# %%
for name in df['Name']:
  print(name.upper())
# Out:
# A
# B
# C
# D
# E
# F
# G
# H
# I
# J

# %%
import numpy as np
df['Age'].apply(np.sqrt)
# Out:
# 0    3.162278
# 1    3.000000
# 2    2.828427
# 3    2.645751
# 4    2.449490
# 5    2.236068
# 6    2.000000
# 7    1.732051
# 8    1.414214
# 9    3.872983
# Name: Age, dtype: float64

# %%
df.groupby('Gender').apply(lambda x: x.count())
# Out:
#         Name  Age  Roll no  Gender
# Gender
# F          5    5        5       5
# M          5    5        5       5
